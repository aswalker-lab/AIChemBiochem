# %% [markdown]
# # Biochemistry Classifier exercise
# For this exercise, we will build classifiers for the classifying if a peptde has a signal peptide (original source: https://services.healthtech.dtu.dk/services/SignalP-6.0/3-Data.php), that affects trafficking of the peptide. For both the train and test datasets, there is a fasta file with the sequences and a csv file with the classifications, Files are: train_set_seqs.fasta, test_set_seqs.fasta, train_set_classifications.csv, test_set_classifications.csv

# %%
#template for exercise 2b
#use scikit-learn metrics for all metrics

class SignalPeptideClassifiers():
    #initialize with the dataframe containing the training data
    def __init__(self, train_fasta_filename, train_csv_filename):
        # create and train a support vector machine classifier, using SVC from scikit-learn, that predicts if a peptide has a signal peptide
        # use the counts of all 20 amino acids as features, order them alphabetically by one letter code
        # use the following hyperparameters: C=0.8 and a 3rd dgree polynomial kernel
        # in addition to setting the hyperparamters as above set random_state=42, this ensures your answer does not vary from the autograder due to different random numbers
        # leave all other options as the default when creating SVC
        
        
        # create and train a random forest classifier, using RandomForestClassifier from scikit-learn, that predicts if a peptide has a signal peptide
        # use the counts of all 20 amino acids as features, order them alphabetically by one letter code
        # use the following hyperparameters: number of estimators = 10 and minimum number of samples per leaf of 5
        # in addition to setting the hyperparamters as above set random_state=42, this ensures your answer does not vary from the autograder due to different random numbers
        # leave all other options as the default when creating the RandomForest
        
    # return the SVC's accuracy, precision, and recall for test data
    def svc_metrics(self, test_fast_filename, test_csv_filename):
        return
    
    # return the random forests's accuracy, precision, recall, and area under the ROC for test data
    def rf_metrics(self, test_fast_filename, test_csv_filename):
        return
