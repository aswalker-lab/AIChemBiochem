# %% [markdown]
# # Chemistry Classifier exercise
# For this exercise, we will build classifiers for the Ames mutagencity dataset (original source:https://doc.ml.tu-berlin.de/toxbenchmark/index.html#v2), which measures if a compound is a mutagen. ames_train.csv and ames_test.csv are provided as training and test data. The label for classification is in the Activity column.

# %%
#template for exercise 2a
#use scikit-learn metrics for all metrics

class AmesClassifiers():
    #initialize with the dataframe containing the training data
    def __init__(self, train_df):
        # create and train a support vector machine classifier, using SVC from scikit-learn, that predicts mutagencity
        # use the following features for this model: number of aromatic rings, total polar surface area
        # keep features in the same order as these instructions
        # use the following hyperparameters: C=0.8 and a 3rd dgree polynomial kernel
        # in addition to setting the hyperparamters as above set random_state=42, this ensures your answer does not vary from the autograder due to different random numbers
        # leave all other options as the default when creating SVC
        
        
        # create and train a random forest classifier, using RandomForestClassifier from scikit-learn, that predicts mutagenicty from chemical fingerprint
        # for the fingerprint use GetMorganGenerator with radius of 2 and fingerprint size of 2048
        # use the following hyperparameters: number of estimators = 10 and minimum number of samples per leaf of 5
        # in addition to setting the hyperparamters as above set random_state=42, this ensures your answer does not vary from the autograder due to different random numbers
        # leave all other options as the default when creating the RandomForest
        
    # return the SVC's accuracy, precision, and recall for test_df data
    def svc_metrics(self, test_df):
        return
    
    # return the random forests's accuracy, precision, recall, and area under the ROC for test_df data 
    def rf_metrics(self, test_df):
        return
