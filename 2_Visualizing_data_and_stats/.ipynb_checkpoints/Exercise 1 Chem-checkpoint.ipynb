# %% [markdown]
# # Exercise 1 Chem Template
# In this exercise we will write a class that calculates correltaion between various molecular features (e.g. h bond donor) and solubility. We will also look at how the precense of either a h bond donor or acceptor affects solubility. You do not need to graph any of this data, but it is recommended that you try it for additional practice and to see how the values you get relate to how the graph looks. It is recommended that you use rdkit to calculate all molecular properties. Use the delaney.csv available in this folder of the github as an example to run your code on.

# %%
class SolubilityAnalysis():
    def __init__(self, infile_name):
        self.infile_name = infile_name
        
    #calculate the pearson's correlation between h-bond donors and solubility
    #return correlation, p-value
    def pearson_correlation_h_donor():
        return
    
    #calculate the pearson's correlation between h-bond acceptor and solubility
    #return correlation, p-value
    def pearson_correlation_h_acceptor():
        return
    
    #calculate the pearson's correlation between molecular weight and solubility
    #return correlation, p-value
    def pearson_correlation_mw():
        return
    
    #calculate mann whitney u to compare solubility of compounds that don't have an h-bond donor OR acceptor to those that do
    #return p-value
    def mann_whitney_u_h_bond():
        return
