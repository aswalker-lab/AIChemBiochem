# %% [markdown]
# # Exercise 1 Bio

# %%
class StructureAnalysis():
    def __init__(self, infile_name):
        self.infile_name = infile_name
    
    #calculate Pearson's correlation of R and Rfree - R is a measure of fit of structure to data and Rfree is R with held out data
    #return correlation, p-value
    def pearson_correlation_R_Rfree():
        return
    
    #calculate Pearson's correlation of length of protein and resolution
    #return correlation, p-value
    def pearson_correlation_length_res():
        return
    
    #calculate Pearson's corrleation of the number of amino acids in random coil (C), use sst8 classification and resolution
    #return correlation, p-value
    def pearson_correlation_coil_res():
        return
    
    #perform a Mann Whitney U test to compare the resolution of structures that do have at least one alpha helix and those that dont
    #Helix is indicated by "H", use sst8
    #return p-value
    def mann_whitney_u_res_alpha_helix():
        return
