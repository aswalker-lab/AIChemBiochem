# %% [markdown]
# # Template for completing Exercise 0
# <br/>Edit the below code to complete the Molecule calc_molecular_weight() function returns the molecular weight and determine_heaviest_atom() returns the symbol of the heavieast atom in the molecule. Atom types used in the moecules for testing this code will be limited to the atoms listed in the atomic weight dictionary
# Suggestions for how to accomplish that while practicing course material is included, although there are likely many
# ways to complete this assignment
# <br/>If you are taking a course using this material, please make sure to follow the course instructions for submission of code

# %%
class Atom:
    #this class can be used to store atom information
    def __init__(self,symbol,atomic_number,atomic_mass):
        self.symbol = symbol
        self.atomic_number = atomic_number
        self.atomic_mass = atomic_mass
    
    #this function will return the atomic weight
    def get_mass(self):
        return self.atomic_mass
    
class Molecule():
    #access these with Molecule.atomic_mass_dictionary or Molecule.atomic_number_dictionary
    atomic_mass_dictionary = {'H': 1.00784, 'C': 12.011,'N': 14.0067,'O':15.999,'Cl':35.45}
    atomic_number_dictionary = {'H':1,'C':6,'N':7,'O':8,'Cl':17}

    def __init__(self, molecular_formula):
        #molecular formula will be a string corresponding to the molecular formula, for example glucose: C6H12O6, only valid formulas will be provided
        """suggested strategy - loop through the molecular formula to identify atoms in the molecule, create an atom object for each
        atom type the molecule, determine how many of that atom is in the molecule from the molecular formula, then add that many of 
        that atom to the atom_list
        hint the string method  isnumeric() and isupper() returns true if all characters are uppercase
        """
        self.atom_list = []
        
    def calc_molecular_weight(self):
        """calculates and returns the molecular weight of the molecule, you need to complete this, do not round and use values 
        provided in the dictionary
        suggested strategy - loop through atoms in atom_list and add up their atomic masses"""
        return
        
    def determine_heaviest_atom(self):
        """returns the symbol of the heaviest atom in the molecule, you need to complete this"""
        return
