# %% [markdown]
# # Chemistry Regression
# We will use the FreeSolv dataset which has the free energy of solvation for different compounds for this exercise. You can use freesolv_train.csv and feesolv_test.csv for testing. The original source of this data is: https://huggingface.co/datasets/scikit-fingerprints/MoleculeNet_FreeSolv and the associated publications are Mobley, D.L., Guthrie, J.P. "FreeSolv: a database of experimental and calculated hydration free energies, with input files" J Comput Aided Mol Des 28, 711–720 (2014) and Wu, Zhenqin, et al. "MoleculeNet: a benchmark for molecular machine learning." Chemical Science 9.2 (2018): 513-530

# %%
# use scikit-learn to calculate all metrics
class FreeSolvRegression():
    #create regressions trained on data contained in the train_file
    def __init__(self, train_file):
        #create and train a linear regression with an elasticnet penalty, using the elasticnet class from scikit-learn
        # for the features use the fingerpint from the GetMorganGenerator with radius of 2 and fingerprint size of 2048
        #use alpha = 0.8, l1_ratio=0.7, and random_state=42
        # use default values for all other parameters
        
        #create and train a SVR using the SVR scikit-learn class
        # use the following features for this model: number of aromatic rings, total polar surface area, molecular weight
        # keep features in the same order as these instructions
        #use an rbf kernel and C=0.9
        #use default values for all other parameters
        
    #return the MAE and R2 score for the elastic net regression for the data in test_file
    def elasticnet_metrics(self, test_file):
        return
    
    # return the MAE and R2 score for the SVR regression for the data in test_file
    def svr_metrics(self, test_file):
        return
