# %% [markdown]
# # Biochemistry Regression
# We will use a dataset of protein solubilities to predict solubility from protien sequence. The original data source is https://github.com/xiaomizhou616/Protein_solubility_regression_model which is from the publication: Han, X., Wang, X., & Zhou, K. (2019). Develop machine learning-based regression predictive models for engineering protein solubility. Bioinformatics, 35(22), 4640-4646. Use the protein_solubility_train.csv and protein_solubility_test.csv files.

# %%
# use scikit-learn to calculate all metrics
class ProteinSolubilityRegression():
    #create regressions trained on data contained in the train_file
    def __init__(self, train_file):
        #create and train a linear regression with an elasticnet penalty, using the elasticnet class from scikit-learn
        #use the fraction of each amino acid (number of amino acid/lenth of sequence) as features
        #put the features in alphabetical order by single letter amino acid code
        #use alpha = 0.8, l1_ratio=0.7, and random_state=42
        # use default values for all other parameters
        
        #create and train a SVR using the SVR scikit-learn class
        #use the fraction of each amino acid (number of amino acid/lenth of sequence) as features
        #put the features in alphabetical order by single letter amino acid code
        #use an rbf kernel and C=0.9
        #use default values for all other parameters
    
    #return the MAE and R2 score for the elastic net regression for the data in test_file
    def elasticnet_metrics(self, test_file):
        return
    
    # return the MAE and R2 score for the SVR regression for the data in test_file
    def svr_metrics(self,test_file):
        return
